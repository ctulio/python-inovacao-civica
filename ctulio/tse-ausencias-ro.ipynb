# %%
import pandas as pd
pd.options.display.max_columns = None

# %%
ausencias_ro = pd.read_csv('ausencias-ro.csv', sep=';', encoding='iso-8859-1')

# %%
ausencias_ro.head(3)
# Out:
#    NR_TURNO SG_UF  CD_MUNICIPIO        NM_MUNICIPIO  NR_ZONA  CD_GENERO  \
# 0         1    RO           477  CANDEIAS DO JAMARI       21          4
# 1         1    RO           477  CANDEIAS DO JAMARI       21          4
# 2         1    RO           477  CANDEIAS DO JAMARI       21          4
#
#   DS_GENERO  CD_ESTADO_CIVIL DS_ESTADO_CIVIL  CD_FAIXA_ETARIA DS_FAIXA_ETARIA  \
# 0  FEMININO                1        SOLTEIRO             1700         17 anos
# 1  FEMININO                1        SOLTEIRO             1900         19 anos
# 2  FEMININO                1        SOLTEIRO             2124    21 a 24 anos
#
#    CD_GRAU_ESCOLARIDADE DS_GRAU_ESCOLARIDADE  QT_APTOS  QT_COMPARECIMENTO  \
# 0                     1           ANALFABETO         1                  1
# 1                     7  SUPERIOR INCOMPLETO         8                  7
# 2                     1           ANALFABETO         1                  1
#
# ...

# %%
colunas =['NR_TURNO', 'DS_FAIXA_ETARIA','NR_ZONA', 'QT_APTOS', 'QT_ABSTENCAO','QT_COMPARECIMENTO_TTE', 'DS_GRAU_ESCOLARIDADE', 'CD_GRAU_ESCOLARIDADE' ]

filtro = ((ausencias_ro['NM_MUNICIPIO'] == 'PORTO VELHO') &
          (ausencias_ro['DS_GENERO'] == 'MASCULINO') &
         (ausencias_ro['DS_FAIXA_ETARIA'] == '16 anos') &
         (ausencias_ro['DS_ESTADO_CIVIL'] == 'SOLTEIRO')&
          (ausencias_ro['NR_ZONA'] == 6)#&
          #(ausencias_ro['DS_GRAU_ESCOLARIDADE'] == 'SUPERIOR INCOMPLETO') 
          
         )

a = ausencias_ro.loc[filtro, colunas]
a.sort_values(by=['NR_TURNO', 'CD_GRAU_ESCOLARIDADE'], ascending = True, na_position = 'first', ignore_index = False)
# Out:
#        NR_TURNO DS_FAIXA_ETARIA  NR_ZONA  QT_APTOS  QT_ABSTENCAO  \
# 15139         1         16 anos        6         1             0
# 36319         1         16 anos        6         1             1
# 5602          1         16 anos        6       100            48
# 30808         1         16 anos        6        18             8
# 36320         1         16 anos        6       279            70
# 11788         1         16 anos        6        53            10
# 31088         1         16 anos        6         1             0
# 32650         1         16 anos        6         9             1
# 573           2         16 anos        6         1             1
# 41044         2         16 anos        6         1             1
# 2371          2         16 anos        6       100            60
# 42636         2         16 anos        6        18             7
# 41045         2         16 anos        6       279            93
# ...

# %%
colunas = list(ausencias_ro.columns)

colunas
# Out:
# ['NR_TURNO',
#  'SG_UF',
#  'CD_MUNICIPIO',
#  'NM_MUNICIPIO',
#  'NR_ZONA',
#  'CD_GENERO',
#  'DS_GENERO',
#  'CD_ESTADO_CIVIL',
#  'DS_ESTADO_CIVIL',
#  'CD_FAIXA_ETARIA',
#  'DS_FAIXA_ETARIA',
#  'CD_GRAU_ESCOLARIDADE',
#  'DS_GRAU_ESCOLARIDADE',
#  'QT_APTOS',
#  'QT_COMPARECIMENTO',
#  'QT_ABSTENCAO',
#  'QT_COMPARECIMENTO_DEFICIENCIA',
#  'QT_ABSTENCAO_DEFICIENCIA',
#  'QT_COMPARECIMENTO_TTE',
#  'QT_ABSTENCAO_TTE']
